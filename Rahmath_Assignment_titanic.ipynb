# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1 Load the dataset into python environment

# %%
data=pd.read_csv(r'C:\Users\DELL\Downloads\titanic_dataset.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# # 2. Make ‘PassengerId’ as the index column

# %%
data.set_index('PassengerId')
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# 887                                      Montvila, Rev. Juozas    male  27.0
# 888                               Graham, Miss. Margaret Edith  female  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 890                                      Behr, Mr. Karl Howell    male  26.0
# 891                                        Dooley, Mr. Patrick    male  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %% [markdown]
# # 3. Check the basic details of the dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
data.shape
# Out:
# (891, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 4. Fill in all the missing values present in all the columns in the dataset

# %%
#filling the missing values in the 'Age' column with median
data['Age']=data['Age'].fillna(data['Age'].median())
data['Age'].isna().sum()
# Out:
# 0

# %%
#filling  the 'Embarked' column with mode
data['Embarked']=data['Embarked'].fillna(data['Embarked'].mode()[0])

# %%
data.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
data.Cabin.nunique()
# Out:
# 147

# %%
data['Cabin']=data['Cabin'].fillna(method='bfill')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   C85        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250  C123        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   E46        S

# %% [markdown]
# # 5. Check and handle outliers in at least 3 columns in the dataset

# %%
# 1. First one
#checking outliers
import seaborn as sns
sns.boxplot(y='Age',data=data)
# Out:
# <Axes: ylabel='Age'>

# %%
#finding outliers
import numpy as np
Q1 = np.percentile(data['Age'],25,interpolation='midpoint')
Q2 = np.percentile(data['Age'],50,interpolation='midpoint')
Q3 = np.percentile(data['Age'],75,interpolation='midpoint')
IQR = Q3 - Q1
low_limit = Q1 - 1.5*IQR
upp_limit = Q3 + 1.5*IQR
print('Q1 is:',Q1)
print('Q2 is:',Q2)
print('Q3 is:',Q3)
print('IQR = Q3 - Q1 =',IQR)
print('Lower limit is :',low_limit)
print('Upper limit is :',upp_limit)
Outliers=[]
for x in data['Age']:
    if ((x>upp_limit) or (x<low_limit)):
        Outliers.append(x)
print('Outliers are :\n',Outliers)
# Out:
# Q1 is: 22.0
# Q2 is: 28.0
# Q3 is: 35.0
# IQR = Q3 - Q1 = 13.0
# Lower limit is : 2.5
# Upper limit is : 54.5
# Outliers are :
#  [2.0, 58.0, 55.0, 2.0, 66.0, 65.0, 0.83, 59.0, 71.0, 70.5, 2.0, 55.5, 1.0, 61.0, 1.0, 56.0, 1.0, 58.0, 2.0, 59.0, 62.0, 58.0, 63.0, 65.0, 2.0, 0.92, 61.0, 2.0, 60.0, 1.0, 1.0, 64.0, 65.0, 56.0, 0.75, 2.0, 63.0, 58.0, 55.0, 71.0, 2.0, 64.0, 62.0, 62.0, 60.0, 61.0, 57.0, 80.0, 2.0, 0.75, 56.0, 58.0, 70.0, 60.0, 60.0, 70.0, 0.67, 57.0, 1.0, 0.42, 2.0, 1.0, 62.0, 0.83, 74.0, 56.0]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\3399158025.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(data['Age'],25,interpolation='midpoint')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\3399158025.py:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q2 = np.percentile(data['Age'],50,interpolation='midpoint')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\3399158025.py:5: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(data['Age'],75,interpolation='midpoint')

# %%
#finding index of Outliers
ind1 = data['Age']>upp_limit
data.loc[ind1].index
# Out:
# Int64Index([ 11,  15,  33,  54,  94,  96, 116, 152, 170, 174, 195, 232, 252,
#             268, 275, 280, 326, 366, 438, 456, 467, 483, 487, 492, 493, 545,
#             555, 570, 587, 625, 626, 630, 647, 659, 672, 684, 694, 745, 772,
#             829, 851, 879],
#            dtype='int64')

# %%
ind2 = data['Age']<low_limit
data.loc[ind2].index
# Out:
# Int64Index([  7,  16,  78, 119, 164, 172, 183, 205, 297, 305, 340, 381, 386,
#             469, 479, 530, 642, 644, 755, 788, 803, 824, 827, 831],
#            dtype='int64')

# %%
#removing outliers
data.drop([8,  17,  79, 120, 165, 173, 184, 206, 298, 306, 341, 382, 387,
            470, 480, 531, 643, 645, 756, 789, 804, 825, 828, 832,12,  16,  34,  55,  95,  97, 117, 153, 171, 175, 196, 233, 253,
            269, 276, 281, 327, 367, 439, 457, 468, 484, 488, 493, 494, 546,
            556, 571, 588, 626, 627, 631, 648, 660, 673, 685, 695, 746, 773,
            830, 852, 880],inplace=True)

# %%
#checking whether outliers are removed
import seaborn as sns
sns.boxplot(y='Age',data=data)
# Out:
# <Axes: ylabel='Age'>

# %%
#2. Second one
#checking outliers
import seaborn as sns
sns.boxplot(x='Fare',data=data)
# Out:
# <Axes: xlabel='Fare'>

# %%
#finding outliers
Q1 = np.percentile(data['Fare'],25,interpolation='midpoint')
Q2 = np.percentile(data['Fare'],50,interpolation='midpoint')
Q3 = np.percentile(data['Fare'],75,interpolation='midpoint')
IQR = Q3 - Q1
low_limit = Q1 - 1.5*IQR
upp_limit = Q3 + 1.5*IQR
print('Q1 is:',Q1)
print('Q2 is:',Q2)
print('Q3 is:',Q3)
print('IQR = Q3 - Q1 =',IQR)
print('Lower limit is :',low_limit)
print('Upper limit is :',upp_limit)


Outliers=[]
for x in data['Fare']:
    if ((x>upp_limit) or (x<low_limit)):
        Outliers.append(x)
print('Outliers are :\n',Outliers)
# Out:
# Q1 is: 7.8958
# Q2 is: 14.4542
# Q3 is: 30.6958
# IQR = Q3 - Q1 = 22.799999999999997
# Lower limit is : -26.304199999999994
# Upper limit is : 64.8958
# Outliers are :
#  [71.2833, 263.0, 146.5208, 76.7292, 80.0, 83.475, 73.5, 263.0, 77.2875, 247.5208, 77.2875, 79.2, 66.6, 69.55, 69.55, 146.5208, 69.55, 113.275, 76.2917, 90.0, 83.475, 90.0, 79.2, 86.5, 512.3292, 79.65, 153.4625, 77.9583, 78.85, 91.0792, 151.55, 247.5208, 151.55, 108.9, 83.1583, 262.375, 164.8667, 134.5, 69.55, 135.6333, 153.4625, 133.65, 66.6, 134.5, 75.25, 69.3, 135.6333, 82.1708, 211.5, 227.525, 73.5, 120.0, 113.275, 90.0, 120.0, 263.0, 81.8583, 89.1042, 90.0, 78.2667, 151.55, 86.5, 108.9, 93.5, 221.7792, 106.425, 71.0, 106.425, 110.8833, 227.525, 79.65, 110.8833, 79.65, 79.2, 78.2667, 153.4625, 65.0, 69.3, 73.5, 113.275, 73.5, 512.3292, 76.7292, 211.3375, 110.8833, 227.525, 151.55, 227.525, 211.3375, 512.3292, 78.85, 262.375, 71.0, 65.0, 86.5, 120.0, 77.9583, 211.3375, 69.55, 120.0, 93.5, 80.0, 83.1583, 69.55, 89.1042, 164.8667, 69.55, 83.1583]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\59740294.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(data['Fare'],25,interpolation='midpoint')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\59740294.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q2 = np.percentile(data['Fare'],50,interpolation='midpoint')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\59740294.py:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(data['Fare'],75,interpolation='midpoint')

# %%
#Tfind index of Outliers
ind1 = data['Fare']>upp_limit
data.loc[ind1].index
# Out:
# Int64Index([  1,  27,  31,  52,  61,  62,  72,  88, 102, 118,
#             ...
#             792, 802, 820, 829, 835, 846, 849, 856, 863, 879],
#            dtype='int64', length=108)

# %%
ind2 = data['Fare']<low_limit
data.loc[ind2].index
# Out:
# Int64Index([], dtype='int64')

# %%
data.drop(data.loc[ind1].index,inplace=True)

# %%
#checking whether outliers are removed
sns.boxplot(x='Fare',data=data)
# Out:
# <Axes: xlabel='Fare'>

# %%
#3.Third one
#checking outliers
sns.boxplot(y='Sex',x='Fare',data=data)
# Out:
# <Axes: xlabel='Fare', ylabel='Sex'>

# %%
#grouping data for male
data1=data.groupby('Sex').get_group('male')
data1
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 0    22.0      1      0         A/5 21171   7.2500   C85        S
# 4    35.0      0      0            373450   8.0500   E46        S
# 5    28.0      0      0            330877   8.4583   E46        Q
# 6    54.0      0      0             17463  51.8625   E46        S
# 7     2.0      3      1            349909  21.0750    G6        S
# ..    ...    ...    ...               ...      ...   ...      ...
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   B42        S
# 884  25.0      0      0   SOTON/OQ 392076   7.0500   B42        S
# 886  27.0      0      0            211536  13.0000   B42        S
# 889  26.0      0      0            111369  30.0000  C148        C
# 890  32.0      0      0            370376   7.7500   NaN        Q
#
# [490 rows x 12 columns]

# %%
#finding Outliers
Q1 = np.percentile(data1['Fare'],25,interpolation='midpoint')
Q2 = np.percentile(data1['Fare'],50,interpolation='midpoint')
Q3 = np.percentile(data1['Fare'],75,interpolation='midpoint')
IQR = Q3 - Q1
low_limit = Q1 - 1.5*IQR
upp_limit = Q3 + 1.5*IQR
print('Q1 is:',Q1)
print('Q2 is:',Q2)
print('Q3 is:',Q3)
print('IQR = Q3 - Q1 =',IQR)
print('Lower limit is :',low_limit)
print('Upper limit is :',upp_limit)
Outliers=[]
for x in data1['Fare']:
    if ((x>upp_limit) or (x<low_limit)):
        Outliers.append(x)
print('Outliers are :\n',Outliers)
# Out:
# Q1 is: 7.8542
# Q2 is: 9.5
# Q3 is: 26.0
# IQR = Q3 - Q1 = 18.1458
# Lower limit is : -19.364500000000003
# Upper limit is : 53.2187
# Outliers are :
#  [61.9792, 56.4958, 61.175, 61.3792, 56.4958, 55.4417, 55.9, 56.4958, 56.9292, 57.0, 56.4958, 56.4958, 56.4958]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\2553950218.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(data1['Fare'],25,interpolation='midpoint')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\2553950218.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q2 = np.percentile(data1['Fare'],50,interpolation='midpoint')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\2553950218.py:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(data1['Fare'],75,interpolation='midpoint')

# %%
#finging index of Outliers
ind1 = data1['Fare']>upp_limit
data1.loc[ind1].index
# Out:
# Int64Index([54, 74, 92, 155, 169, 370, 434, 509, 599, 690, 692, 826, 838], dtype='int64')

# %%
ind2 = data1['Fare']<low_limit
data1.loc[ind2].index
# Out:
# Int64Index([], dtype='int64')

# %%
#grouping data for female
data2=data.groupby('Sex').get_group('female')
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 3              4         1       1
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 875          876         1       3
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 2                          Heikkinen, Miss. Laina  female  26.0      0      0
# 3    Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 9             Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1      0
# 10                Sandstrom, Miss. Marguerite Rut  female   4.0      1      1
# 11                       Bonnell, Miss. Elizabeth  female  58.0      0      0
# ..                                            ...     ...   ...    ...    ...
# 875              Najib, Miss. Adele Kiamie "Jane"  female  15.0      0      0
# 882                  Dahlberg, Miss. Gerda Ulrika  female  22.0      0      0
# 885          Rice, Mrs. William (Margaret Norton)  female  39.0      0      5
# 887                  Graham, Miss. Margaret Edith  female  19.0      0      0
# 888      Johnston, Miss. Catherine Helen "Carrie"  female  28.0      1      2
#
#                Ticket     Fare Cabin Embarked
# 2    STON/O2. 3101282   7.9250  C123        S
# 3              113803  53.1000  C123        S
# 9              237736  30.0708    G6        C
# 10            PP 9549  16.7000    G6        S
# 11             113783  26.5500  C103        S
# ..                ...      ...   ...      ...
# 875              2667   7.2250   C50        C
# 882              7552  10.5167   B42        S
# 885            382652  29.1250   B42        Q
# 887            112053  30.0000   B42        S
# 888        W./C. 6607  23.4500  C148        S
#
# [227 rows x 12 columns]

# %%
#finding Outliers
Q1 = np.percentile(data2['Fare'],25,interpolation='midpoint')
Q2 = np.percentile(data2['Fare'],50,interpolation='midpoint')
Q3 = np.percentile(data2['Fare'],75,interpolation='midpoint')
IQR = Q3 - Q1
low_limit = Q1 - 1.5*IQR
upp_limit = Q3 + 1.5*IQR
print('Q1 is:',Q1)
print('Q2 is:',Q2)
print('Q3 is:',Q3)
print('IQR = Q3 - Q1 =',IQR)
print('Lower limit is :',low_limit)
print('Upper limit is :',upp_limit)
Outliers=[]
for x in data2['Fare']:
    if ((x>upp_limit) or (x<low_limit)):
        Outliers.append(x)
print('Outliers are :\n',Outliers)
# Out:
# Q1 is: 9.5875
# Q2 is: 15.7417
# Q3 is: 26.0
# IQR = Q3 - Q1 = 16.4125
# Lower limit is : -15.031250000000002
# Upper limit is : 50.618750000000006
# Outliers are :
#  [53.1, 55.0, 56.9292, 57.9792, 55.0, 52.0, 59.4, 57.9792, 55.9, 52.0, 57.0, 53.1, 52.5542]
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\2260807251.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(data2['Fare'],25,interpolation='midpoint')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\2260807251.py:3: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q2 = np.percentile(data2['Fare'],50,interpolation='midpoint')
# C:\Users\DELL\AppData\Local\Temp\ipykernel_9824\2260807251.py:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(data2['Fare'],75,interpolation='midpoint')

# %%
#finding index of Outliers
ind1 = data2['Fare']>upp_limit
data2.loc[ind1].index
# Out:
# Int64Index([3, 166, 309, 329, 356, 383, 513, 523, 577, 669, 781, 809, 871], dtype='int64')

# %%
ind2 = data2['Fare']<low_limit
data2.loc[ind2].index
# Out:
# Int64Index([], dtype='int64')

# %%
#checking whether outliers are removed
sns.boxplot(y='Sex',x='Fare',data=data)
# Out:
# <Axes: xlabel='Fare', ylabel='Sex'>

# %% [markdown]
# # 6. Do min max scaling on the feature set (Take ‘Survived’ as target)

# %%
x=data.drop(['Name','Sex','Ticket','Embarked','Cabin'],axis=1)
x.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   717.000000  717.000000  717.000000  717.000000  717.000000
# mean    446.362622    0.333333    2.475593   28.798815    0.428173
# std     259.833971    0.471734    0.736918   12.749513    0.879270
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     217.000000    0.000000    2.000000   22.000000    0.000000
# 50%     448.000000    0.000000    3.000000   28.000000    0.000000
# 75%     671.000000    1.000000    3.000000   34.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    5.000000
#
#             Parch        Fare
# count  717.000000  717.000000
# mean     0.333333   17.610215
# std      0.788653   13.248631
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   12.875000
# 75%      0.000000   26.000000
# max      6.000000   61.979200

# %%
from sklearn import preprocessing
min_max=preprocessing.MinMaxScaler(feature_range=(0,1))
x=min_max.fit_transform(x)
x=pd.DataFrame(x)
x.describe()
# Out:
#                 0           1           2           3           4           5  \
# count  717.000000  717.000000  717.000000  717.000000  717.000000  717.000000
# mean     0.500407    0.333333    0.737796    0.356607    0.085635    0.055556
# std      0.291948    0.471734    0.368459    0.160210    0.175854    0.131442
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.242697    0.000000    0.500000    0.271174    0.000000    0.000000
# 50%      0.502247    0.000000    1.000000    0.346569    0.000000    0.000000
# 75%      0.752809    1.000000    1.000000    0.421965    0.200000    0.000000
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                 6
# count  717.000000
# mean     0.284131
# std      0.213759
# min      0.000000
# 25%      0.127394
# 50%      0.207731
# 75%      0.419496
# max      1.000000
